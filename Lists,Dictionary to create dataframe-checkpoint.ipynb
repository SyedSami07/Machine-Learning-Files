# %%
#import library
import pandas as pd

# %%
#empty df
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
#ekta list nilam
city = ['berlin', 'elrangen', 'zurich']

# %%
city
# Out:
# ['berlin', 'elrangen', 'zurich']

# %%
#list to dataframe convert
df = pd.DataFrame(city)
df
# Out:
#           0
# 0    berlin
# 1  elrangen
# 2    zurich

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(city)
# Out:
# list

# %%
row,col = df.shape

# %%
row
# Out:
# 3

# %%
col
# Out:
# 1

# %%
#shuru te thakbe row, them column shongkha
df.shape
# Out:
# (3, 1)

# %%
#set column name
df = pd.DataFrame(city, columns=['city_in_Europe'])
df
# Out:
#   city_in_Europe
# 0         berlin
# 1       elrangen
# 2         zurich

# %%
#set row name
df = pd.DataFrame(city, columns=['city_in_Europe'], index=['c1','c2','c3']) #index akare city name dilam
df
# Out:
#    city_in_Europe
# c1         berlin
# c2       elrangen
# c3         zurich

# %%
#making another list
city2 = ['dortmund', 'paris','potsdam']
df2 = pd.DataFrame(zip(city,city2),columns=['city1','city2'])

# %%
df2
# Out:
#       city1     city2
# 0    berlin  dortmund
# 1  elrangen     paris
# 2    zurich   potsdam

# %%
#3 rows, 2 columns
df2.shape
# Out:
# (3, 2)

# %%
#2d list making
city3 = [['bavaria','erlangen'], ['NRW', 'Dortmund']]

# %%
city3
# Out:
# [['bavaria', 'erlangen'], ['NRW', 'Dortmund']]

# %%
#2d list columns name setting
df4 = pd.DataFrame(city3, columns = ['state', 'city'])
df4
# Out:
#      state      city
# 0  bavaria  erlangen
# 1      NRW  Dortmund

# %%
city
# Out:
# ['berlin', 'elrangen', 'zurich']

# %%
city2
# Out:
# ['dortmund', 'paris', 'potsdam']

# %%
#making dictionary
dict1 = {
    'city1':city,
    'city2':city2
}

# %%
dict1
# Out:
# {'city1': ['berlin', 'elrangen', 'zurich'],
#  'city2': ['dortmund', 'paris', 'potsdam']}

# %%
#dictionary to dataframe convert
df5 = pd.DataFrame(dict1)
df5
# Out:
#       city1     city2
# 0    berlin  dortmund
# 1  elrangen     paris
# 2    zurich   potsdam

# %%
type(dict1)
# Out:
# dict

# %%
#importing excel file
df = pd.read_csv('Screen Time Data.csv')
df
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 1       1  04/18/19   Thursday                 123                 78
# 2       2  04/19/19     Friday                 112                 52
# 3       3  04/20/19   Saturday                 101                 69
# 4       4  04/21/19     Sunday                  56                 35
# 5       5  04/22/19     Monday                 189                 68
# 6       6  04/23/19    Tuesday                 158                 56
# 7       7  04/24/19  Wednesday                 135                 98
# 8       8  04/25/19   Thursday                  52                 25
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 11     11  04/28/19     Sunday                  85                 42
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head() #first 5 rows
# Out:
#    index      Date   Week Day  Total Screen Time   Social Networking  \
# 0      0  04/17/19  Wednesday                 187                 89
# 1      1  04/18/19   Thursday                 123                 78
# 2      2  04/19/19     Friday                 112                 52
# 3      3  04/20/19   Saturday                 101                 69
# 4      4  04/21/19     Sunday                  56                 35
#
#    Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                     17     41            22                   0
# 1                     17      8             9                   0
# 2                     40      8             4                   0
# 3                      9     38             2                   0
# 4                      2     43             3                   0
#
#    Entertainment  Creativity  Yoga
# 0              0           0     0
# 1              0           0     0
# 2              3           0     0
# ...

# %%
df.tail() #last 5 rows
# Out:
#     index      Date  Week Day  Total Screen Time   Social Networking  \
# 23     23  05/10/19    Friday                 161                 93
# 24     24  05/11/19  Saturday                  58                 49
# 25     25  05/12/19    Sunday                  52                 28
# 26     26  05/13/19    Monday                  61                 37
# 27     27  05/14/19   Tuesday                  88                 41
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 23                     13     17            16                   1
# 24                      1      2             2                   0
# 25                      1      1             6                   0
# 26                      1      0             4                   0
# 27                      2      7            15                   0
#
#     Entertainment  Creativity  Yoga
# 23              0           0     1
# 24              0           2     1
# ...

# %%
df.values
# Out:
# array([[0, '04/17/19', 'Wednesday', 187, 89, 17, 41, 22, 0, 0, 0, 0],
#        [1, '04/18/19', 'Thursday', 123, 78, 17, 8, 9, 0, 0, 0, 0],
#        [2, '04/19/19', 'Friday', 112, 52, 40, 8, 4, 0, 3, 0, 0],
#        [3, '04/20/19', 'Saturday', 101, 69, 9, 38, 2, 0, 3, 0, 0],
#        [4, '04/21/19', 'Sunday', 56, 35, 2, 43, 3, 0, 1, 1, 0],
#        [5, '04/22/19', 'Monday', 189, 68, 0, 9, 3, 4, 0, 0, 0],
#        [6, '04/23/19', 'Tuesday', 158, 56, 18, 41, 12, 15, 0, 0, 0],
#        [7, '04/24/19', 'Wednesday', 135, 98, 3, 33, 16, 0, 0, 0, 0],
#        [8, '04/25/19', 'Thursday', 52, 25, 7, 3, 16, 0, 0, 0, 0],
#        [9, '04/26/19', 'Friday', 198, 76, 8, 29, 15, 0, 32, 0, 0],
#        [10, '04/27/19', 'Saturday', 116, 75, 10, 20, 5, 0, 0, 0, 0],
#        [11, '04/28/19', 'Sunday', 85, 42, 22, 4, 2, 0, 0, 0, 0],
#        [12, '04/29/19', 'Monday', 109, 46, 8, 13, 9, 15, 1, 0, 1],
#        [13, '04/30/19', 'Tuesday', 79, 40, 2, 9, 12, 0, 0, 0, 1],
# ...

# %%
df.columns
# Out:
# Index(['index', 'Date', 'Week Day', 'Total Screen Time ', 'Social Networking',
#        'Reading and Reference', 'Other', 'Productivity', 'Health and Fitness',
#        'Entertainment', 'Creativity', 'Yoga'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=28, step=1)

# %%
df
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 1       1  04/18/19   Thursday                 123                 78
# 2       2  04/19/19     Friday                 112                 52
# 3       3  04/20/19   Saturday                 101                 69
# 4       4  04/21/19     Sunday                  56                 35
# 5       5  04/22/19     Monday                 189                 68
# 6       6  04/23/19    Tuesday                 158                 56
# 7       7  04/24/19  Wednesday                 135                 98
# 8       8  04/25/19   Thursday                  52                 25
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 11     11  04/28/19     Sunday                  85                 42
# ...

# %%
df[['Social Networking']].head(5)
# Out:
#    Social Networking
# 0                 89
# 1                 78
# 2                 52
# 3                 69
# 4                 35

# %%
df.Date.head(5)
# Out:
# 0    04/17/19
# 1    04/18/19
# 2    04/19/19
# 3    04/20/19
# 4    04/21/19
# Name: Date, dtype: object

# %%
df[['Social Networking','Date','Week Day']].head(5)
# Out:
#    Social Networking      Date   Week Day
# 0                 89  04/17/19  Wednesday
# 1                 78  04/18/19   Thursday
# 2                 52  04/19/19     Friday
# 3                 69  04/20/19   Saturday
# 4                 35  04/21/19     Sunday

# %%
df['Social Networking'].sort_values().head(5)
# Out:
# 8     25
# 25    28
# 17    34
# 4     35
# 26    37
# Name: Social Networking, dtype: int64

# %%
df.sort_values('Social Networking',ascending=True).head(5)
# Out:
#     index      Date  Week Day  Total Screen Time   Social Networking  \
# 8       8  04/25/19  Thursday                  52                 25
# 25     25  05/12/19    Sunday                  52                 28
# 17     17  05/04/19  Saturday                  58                 34
# 4       4  04/21/19    Sunday                  56                 35
# 26     26  05/13/19    Monday                  61                 37
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 8                       7      3            16                   0
# 25                      1      1             6                   0
# 17                      4      5             3                   0
# 4                       2     43             3                   0
# 26                      1      0             4                   0
#
#     Entertainment  Creativity  Yoga
# 8               0           0     0
# 25              0           1     1
# ...

# %%
df.describe()
# Out:
#            index  Total Screen Time   Social Networking  \
# count  28.000000           28.000000          28.000000
# mean   13.500000          113.250000          60.714286
# std     8.225975           43.562322          22.853571
# min     0.000000           52.000000          25.000000
# 25%     6.750000           83.500000          41.750000
# 50%    13.500000          111.000000          58.000000
# 75%    20.250000          137.250000          76.500000
# max    27.000000          198.000000         109.000000
#
#        Reading and Reference      Other  Productivity  Health and Fitness  \
# count              28.000000  28.000000     28.000000           28.000000
# mean                8.714286  14.821429      9.071429            1.285714
# std                 9.340700  13.754605      6.097532            3.952094
# min                 0.000000   0.000000      2.000000            0.000000
# 25%                 2.000000   4.750000      3.000000            0.000000
# ...

# %%
df['Social Networking'] > 50
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# 8     False
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# 14     True
# 15     True
# 16     True
# 17    False
# 18     True
# 19     True
# 20     True
# 21     True
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# Name: Social Networking, dtype: bool

# %%
df[df['Social Networking'] > 50]
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 1       1  04/18/19   Thursday                 123                 78
# 2       2  04/19/19     Friday                 112                 52
# 3       3  04/20/19   Saturday                 101                 69
# 5       5  04/22/19     Monday                 189                 68
# 6       6  04/23/19    Tuesday                 158                 56
# 7       7  04/24/19  Wednesday                 135                 98
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 14     14  05/01/19  Wednesday                 127                 90
# 15     15  05/02/19   Thursday                 170                 60
# 16     16  05/03/19     Friday                  91                 64
# ...
