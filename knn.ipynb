# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('knn.csv')
df
# Out:
#     x   y label
# 0  10  25   red
# 1  40  20   red
# 2  50  50  blue
# 3  25  80  blue
# 4  60  10   red
# 5  70  70  blue
# 6  60  90  blue

# %%
x=df.iloc[:,:-1].values
x
# Out:
# array([[10, 25],
#        [40, 20],
#        [50, 50],
#        [25, 80],
#        [60, 10],
#        [70, 70],
#        [60, 90]], dtype=int64)

# %%
y=df.iloc[:,-1].values
y
# Out:
# array(['red', 'red', 'blue', 'blue', 'red', 'blue', 'blue'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier(n_neighbors=3)
model.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
model.score(x,y)
# Out:
# 1.0

# %%
NewPoint=[[60,110]]
prediction=model.predict(NewPoint)
print('prediction for [20,30] :',prediction)
# Out:
# prediction for [20,30] : ['blue']

# %%
plt.figure(figsize=(8, 6))
plt.scatter(xtrain[:, 0], xtrain[:, 1], c=ytrain, cmap='viridis', marker='o')  # Scatter plot based on features
plt.title('KNN Classifier: Training Data')
plt.xlabel("Feature x")
plt.ylabel("Feature y")
plt.colorbar(label='Label')  # Color legend for labels
plt.show()
# Out:
# C:\Users\farha\AppData\Local\Temp\ipykernel_8944\483799449.py:2: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(xtrain[:, 0], xtrain[:, 1], c=ytrain, cmap='viridis', marker='o')  # Scatter plot based on features
